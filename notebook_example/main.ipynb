# %% [markdown]
# # Notebook Example Pipeline
#
# Beispiel-Notebook für Fast-Flow: Zelle für Zelle ausgeführt, mit Zellen-Retries konfigurierbar in pipeline.json.

# %%
import sys
print('Python:', sys.version)

# %%
# Einfache Berechnung
x = 1 + 2
print(f'1 + 2 = {x}')

# %%
# Demo: Uncomment to test Zellen-Retries (cells[2] = 3 Retries)
# raise Exception('Test-Fehler')
print('Zelle 3: OK')

# %%
print('Notebook-Pipeline abgeschlossen.')
